# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
adult_census = pd.read_csv(r"C:\Users\joshk\Documents\Progamming\mach-learn datasets\adult census\phpMawTba.csv")
adult_census.head()
# Out:
#     age  workclass    fnlwgt     education  education-num      marital-status  \
# 0  25.0    Private  226802.0          11th            7.0       Never-married
# 1  38.0    Private   89814.0       HS-grad            9.0  Married-civ-spouse
# 2  28.0  Local-gov  336951.0    Assoc-acdm           12.0  Married-civ-spouse
# 3  44.0    Private  160323.0  Some-college           10.0  Married-civ-spouse
# 4  18.0        NaN  103497.0  Some-college           10.0       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male           0.0           0.0
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 2    Protective-serv      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                NaN    Own-child  White  Female           0.0           0.0
#
# ...

# %%
target_name = 'class'
target = adult_census[target_name]
target
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: class, Length: 48842, dtype: object

# %%
#remove the target column from the census and create a feature matrix to set the model during fit.
data = adult_census.drop(columns= [target_name])
data.head()
# Out:
#     age  workclass    fnlwgt     education  education-num      marital-status  \
# 0  25.0    Private  226802.0          11th            7.0       Never-married
# 1  38.0    Private   89814.0       HS-grad            9.0  Married-civ-spouse
# 2  28.0  Local-gov  336951.0    Assoc-acdm           12.0  Married-civ-spouse
# 3  44.0    Private  160323.0  Some-college           10.0  Married-civ-spouse
# 4  18.0        NaN  103497.0  Some-college           10.0       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male           0.0           0.0
# 1    Farming-fishing      Husband  White    Male           0.0           0.0
# 2    Protective-serv      Husband  White    Male           0.0           0.0
# 3  Machine-op-inspct      Husband  Black    Male        7688.0           0.0
# 4                NaN    Own-child  White  Female           0.0           0.0
#
#    hours-per-week native-country
# ...

# %%
#This data is

# %%
#Create and object of the class KNC, and fit model to set the model state.
# all code will not work from this point as some data is catorgorical and modeling requires numerical values.

model = KNeighborsClassifier()
_ = model.fit(data, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23556\2723813910.py in ?()
#       1 #Create and object of the class KNC, and fit model to set the model state.
#       2
#       3 model = KNeighborsClassifier()
# ----> 4 _ = model.fit(data, target)
#
# d:\Anaconda\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# d:\Anaconda\Lib\site-packages\sklearn\neighbors\_classification.py in ?(self, X, y)
#     234         -------
#     235         self : KNeighborsClassifier
#     236             The fitted k-nearest neighbors classifier.
#     237         """
# ...

# %%
#create a set of predictions using the same data used to set model state. This should give predictions exactly the same as the results as its the same data.
target_predictions = model.predict(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 #create a set of predictions using the same data used to set model state. This should give predictions exactly the same as the results as its the same data.
# ----> 2 target_predictions = model.predict(data)
#
# NameError: name 'model' is not defined

# %%
# target data from first five samples
target[:5]
# Out:
# 0    <=50K
# 1    <=50K
# 2     >50K
# 3     >50K
# 4    <=50K
# Name: class, dtype: object

# %%
# now first five predicted target values based on sample features supplied
target_predictied
